# %% [markdown]
# # Oligodendrosynth Examples:

# %% [markdown]
# -connectivity distributions for an roi
#
# -connections to targets
#
# -connectivity-based parcellation
#
# -comparing connectivity distributions
#
# -connectivity contrasts
#
# -network analyses
#
# -decoding with neurosynth
#
# -*evaluating whole-brain parcellations

# %%
import nilearn.plotting as nlplt
import numpy as np
import matplotlib.pyplot as plt
import nibabel as nib
import seaborn as sns; sns.set()
import scipy.sparse as ss
import pandas as pd
from test3 import ConnectivityMatrix1
from matplotlib.colors import ListedColormap
# %matplotlib inline

# %%
matrix = ConnectivityMatrix1('testing/test.h5')

# %% [markdown]
# # Connectivity distributions for an roi

# %%
# %time paths = matrix.sum_streamline_count('../mpfc_clusters/masks/MPFC_mask.nii.gz', output='nifti')
# Out:
# CPU times: user 3.47 s, sys: 4.05 s, total: 7.52 s
# Wall time: 9.9 s

# %%
paths = matrix.sum_streamline_count('../mpfc_clusters/masks/MPFC_mask.nii.gz', output='nifti')

# %%
nlplt.plot_stat_map(paths, draw_cross=False)

# %%
from nilearn.image import threshold_img
thres_paths = threshold_img(paths, threshold='97%')
nlplt.plot_stat_map(thres_paths, draw_cross=False)

# %% [markdown]
# # Connections to targets

# %% [markdown]
# We can also look at the connectivity from an roi to some other defined areas. As an example we can look at the connections between each of our MPFC clusters to each of the harvard-oxford labels.

# %%
from nilearn import datasets
dataset = datasets.fetch_atlas_harvard_oxford('cort-maxprob-thr25-2mm')
atlas_filename = dataset.maps
labels = np.array(dataset.labels)
labels = np.delete(labels,0)

# %%
# %time connections = matrix.connections_to_targets('../mpfc_clusters/masks/MPFC_mask.nii.gz',targets=atlas_filename,as_df=True,labels=labels)
# Out:
# CPU times: user 3.42 s, sys: 2.39 s, total: 5.81 s
# Wall time: 6.1 s

# %%
connections = matrix.connections_to_targets('../mpfc_clusters/masks/MPFC_mask.nii.gz',targets=atlas_filename,as_df=True,labels=labels)

# %%
fig = plt.figure(figsize=(10,10))
theta = np.linspace(0.00, 2 * np.pi, len(connections['labels']), endpoint=False)
ax = plt.subplot(111, projection='polar')
ax.plot(theta, connections['percent'],alpha = 0.8, linewidth=4)
ax.set_rmax(.14)
ax.set_rticks([0.02, 0.04, 0.06, 0.08,0.1,0.12,0.18,0.26])  # less radial ticks
ax.set_rlabel_position(-22.5)  # get radial labels away from plotted line
ax.grid(True)
ax.set_xticks(theta)

ax.set_rlabel_position(10)
ax.set_xticklabels(connections['labels'], fontsize=8)
[lab.set_fontsize(8) for lab in ax.get_yticklabels()]

#ax.set_title("vACC cluster connectivity profile", va='bottom')
plt.tight_layout()
plt.show()

# %%
connections
# Out:
#      connections  normalized_connections   percent  \
# 0   1.081931e+10            7.026896e+05  0.133321
# 1   3.913577e+07            1.671755e+04  0.003172
# 2   7.409524e+08            1.458568e+05  0.027673
# 3   8.598062e+07            1.617393e+04  0.003069
# 4   1.598889e+07            1.449582e+04  0.002750
# 5   1.294125e+07            9.350616e+03  0.001774
# 6   4.324234e+07            5.044015e+03  0.000957
# 7   4.731535e+07            1.004359e+04  0.001906
# 8   4.863145e+06            9.334251e+03  0.001771
# 9   1.733723e+07            9.473895e+03  0.001797
# 10  1.282936e+06            1.512897e+03  0.000287
# 11  2.521605e+07            9.986555e+03  0.001895
# 12  1.359075e+07            6.781810e+03  0.001287
# 13  6.930294e+06            1.071143e+04  0.002032
# 14  2.601291e+07            1.339491e+04  0.002541
# 15  4.355408e+06            2.962863e+03  0.000562
# 16  4.851304e+07            7.035974e+03  0.001335
# ...

# %% [markdown]
# # Connectivity-based parcellation

# %% [markdown]
# To do cbp, the under-the-hood operations are very simple. Firstly, we isolate the roi within the matrix resulting in an roi by rest of the brain matrix. An essential step in this data is to standardize the rows. Results won't be interpretable without this step. However, if you wish to proceed without standardization you need only include 'standardize=False' in the function call. Next we find the correlation between each of the rows resulting in an roi x roi correlation matrix. Lastly we run the any of the scikit-learn clustering algorithms or from fastcluster. It returns a nifti.

# %%
# %time matrix.cluster_roi('../mpfc_clusters/masks/MPFC_mask.nii.gz', n_clusters=4)
# Out:
# CPU times: user 2min 43s, sys: 32.8 s, total: 3min 15s
# Wall time: 1min 14s

# %%
clusters = matrix.cluster_roi('../mpfc_clusters/masks/MPFC_mask.nii.gz', n_clusters=4)

# %%
colors = sns.color_palette('Set1', 4)
nlplt.plot_roi(clusters, draw_cross=False, display_mode='x',cmap=ListedColormap(colors))

# %% [markdown]
# # Comparing connectivity distributions

# %% [markdown]
# After we've finished clustering, or if we have some rois that we'd like to compare, we can get a vector of the connectivity distribution for each of the rois in a nifti and return a correlation matrix specifying how similar to connectivity distributions are.

# %%
# %time similarity = matrix.roi_similarity(clusters)
# Out:
# CPU times: user 5.29 s, sys: 3.14 s, total: 8.43 s
# Wall time: 8.02 s

# %%
similarity = matrix.roi_similarity(clusters)

# %%
sns.heatmap(similarity, square=True, annot=True, cbar=True)

# %% [markdown]
# # Connectivity contrasts

# %% [markdown]
# Another way that we can compare the connectivity of several rois is that we can contrast the connectivity of each of the rois against the rest of them to see where in the brain connectivity is greatest per roi.

# %%
# %time contrasts = matrix.connectivity_contrast(clusters)
# Out:
# CPU times: user 17.9 s, sys: 11.3 s, total: 29.2 s
# Wall time: 27.3 s

# %%
contrasts = matrix.connectivity_contrast(clusters)

# %%
for c in contrasts:
    nlplt.plot_stat_map(c, draw_cross=False)

# %% [markdown]
# # Network analyses

# %% [markdown]
# We can also do connectome-style network analyses. We need only pass the function a nifti we the rois. Due to the nature of fsl's fiber tracking algorithm, the resulting matrix will not be symmetrical.

# %%
# %timeit network = matrix.network(atlas_filename)
# Out:
# 4min 21s ± 1.99 s per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
network = matrix.network(atlas_filename)

# %%
normalize = np.array([network[i,:]/network[i,:].sum() for i in range(48)])
normalized_network = pd.DataFrame(normalize, columns=labels, index=labels)

# %%
normalized_network
# Out:
#                                                     Frontal Pole  \
# Frontal Pole                                            0.540239
# Insular Cortex                                          0.109646
# Superior Frontal Gyrus                                  0.295785
# Middle Frontal Gyrus                                    0.128695
# Inferior Frontal Gyrus, pars triangularis               0.194912
# Inferior Frontal Gyrus, pars opercularis                0.050800
# Precentral Gyrus                                        0.050616
# Temporal Pole                                           0.150723
# Superior Temporal Gyrus, anterior division              0.076895
# Superior Temporal Gyrus, posterior division             0.097634
# Middle Temporal Gyrus, anterior division                0.057504
# Middle Temporal Gyrus, posterior division               0.099819
# Middle Temporal Gyrus, temporooccipital part            0.105871
# ...

# %%
import networkx as nx
# Out:
# /anaconda2/envs/python3/lib/python3.6/importlib/_bootstrap.py:219: ImportWarning: can't resolve package from __spec__ or __package__, falling back on __name__ and __path__
#   return f(*args, **kwds)

# %%
mform = np.matrix(normalized_network)

# %%
mform[mform < 0.01] = 0

# %%
cnetwork = nx.from_numpy_matrix(mform)

# %%
cnetwork

# %%
shortest_path = nx.average_shortest_path_length(cnetwork)
avg_clustering = nx.average_clustering(cnetwork)
avg_degree = nx.average_degree_connectivity(cnetwork)

# %%
shortest_path, avg_clustering,avg_degree
# Out:
# (1.5186170212765957,
#  0.7252555362207577,
#  {49: 24.122448979591837,
#   40: 25.425,
#   26: 26.423076923076923,
#   28: 25.178571428571427,
#   25: 26.92,
#   30: 26.166666666666668,
#   34: 25.080882352941178,
#   22: 27.560606060606062,
#   15: 29.2,
#   29: 27.775862068965516,
#   17: 27.91176470588235,
#   19: 27.333333333333332,
#   16: 25.875,
#   31: 26.403225806451612,
#   23: 26.159420289855074,
#   45: 24.644444444444446,
#   13: 24.576923076923077,
#   14: 27.357142857142858,
#   21: 23.833333333333332,
#   24: 27.4375,
#   12: 23.75,
#   20: 28.85,
#   18: 27.555555555555557})
